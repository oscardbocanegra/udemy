# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

olympics = pd.read_csv("/home/david/materiales/04-manipulacion-dataframes-pandas/olympics.csv")

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# One way in where ew can make the filter is by the "mascaras" and basicly it is the result to evaluate a condition on a specific colum

# %%
olympics['NOC'] == 'PER'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: NOC, Length: 271116, dtype: bool

# %%
olympics[olympics['NOC'] == 'PER']
# Out:
#             ID                          Name Sex   Age  Height  Weight  Team  \
# 1076       605  Fernando J. Abugattas Aboino   M  20.0   190.0    80.0  Peru
# 1077       606      Roberto Abugattas Aboino   M  21.0   182.0    77.0  Peru
# 1078       606      Roberto Abugattas Aboino   M  25.0   182.0    77.0  Peru
# 1166       649    Fernando Acevedo Portugues   M  22.0   175.0    65.0  Peru
# 1167       649    Fernando Acevedo Portugues   M  26.0   175.0    65.0  Peru
# ...        ...                           ...  ..   ...     ...     ...   ...
# 267568  133860    Miguel Zambrano de la Cruz   M  28.0   182.0   148.0  Peru
# 267640  133894    Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0  Peru
# 267641  133894    Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0  Peru
# 268048  134100                 Ramn Zavaleta   M  24.0   181.0    72.0  Peru
# 268270  134227  Carlos Erick Zegarra Presser   M  23.0   202.0   165.0  Peru
#
# ...

# %%
olympics.query('NOC == "PER"')
# Out:
#             ID                          Name Sex   Age  Height  Weight  Team  \
# 1076       605  Fernando J. Abugattas Aboino   M  20.0   190.0    80.0  Peru
# 1077       606      Roberto Abugattas Aboino   M  21.0   182.0    77.0  Peru
# 1078       606      Roberto Abugattas Aboino   M  25.0   182.0    77.0  Peru
# 1166       649    Fernando Acevedo Portugues   M  22.0   175.0    65.0  Peru
# 1167       649    Fernando Acevedo Portugues   M  26.0   175.0    65.0  Peru
# ...        ...                           ...  ..   ...     ...     ...   ...
# 267568  133860    Miguel Zambrano de la Cruz   M  28.0   182.0   148.0  Peru
# 267640  133894    Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0  Peru
# 267641  133894    Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0  Peru
# 268048  134100                 Ramn Zavaleta   M  24.0   181.0    72.0  Peru
# 268270  134227  Carlos Erick Zegarra Presser   M  23.0   202.0   165.0  Peru
#
# ...

# %% [markdown]
# Filtros conjuntos

# %%
(olympics['NOC'] == 'PER') & (olympics['Sport'] == 'Volleyball') & (olympics['Year'] == 1988) & (olympics['Medal'] == 'Silver')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
olympics[(olympics['NOC'] == 'PER') & (olympics['Sport'] == 'Volleyball') & (olympics['Year'] == 1988) & (olympics['Medal'] == 'Silver')]
# Out:
#             ID                                             Name Sex   Age  \
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# 242031  121233                                   Gina Torrealva   F  26.0
# 246625  123484                  Cenaida Cebastiana Uribe Medina   F  22.0
#
# ...

# %% [markdown]
# Filtros con comparaciones

# %%
#on this following code I will search a athet that have less tan 20 years
olympics[olympics['Age'] < 20].head()
# Out:
#      ID                                Name Sex   Age  Height  Weight  \
# 26    8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27    8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 87   26        Agnes Erika Aanonsen (-Eyde)   F  17.0   169.0    65.0
# 167  69                   Tamara Abalde Daz   F  19.0   185.0    72.0
# 203  96   Carlos Rodolfo Abaunza Balladares   M  18.0   168.0    60.0
#
#             Team  NOC        Games  Year  Season         City       Sport  \
# 26   Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
# 27   Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
# 87        Norway  NOR  1984 Winter  1984  Winter     Sarajevo        Luge
# 167        Spain  ESP  2008 Summer  2008  Summer      Beijing  Basketball
# 203    Nicaragua  NCA  2004 Summer  2004  Summer       Athina   Athletics
#
#                                       Event Medal
# ...

# %%
#And on here we will see the comparison between 2 colums, that is possible as well.
olympics[olympics['Weight'] > olympics['Height']].head()
# Out:
#           ID               Name Sex   Age  Height  Weight  Team  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              Games  Year  Season     City Sport                   Event Medal
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN

# %% [markdown]
# now we will see that it's possible to create a table with some values of our main data, and then ask for those values

# %%
olympics['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
sports = ['Tennis', 'Table Tennis']
olympics[olympics['Sport'].isin(sports)]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 184         82                Enrique Abaroa Martnez   M  26.0   183.0
# 498        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 499        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 500        277                    Shaimaa Abdul Aziz   F  27.0   160.0
# 582        334              Abubakar Sadiq Abdullahi   M  28.0     NaN
# ...        ...                                   ...  ..   ...     ...
# 270980  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
# 270986  135508              Vera Igorevna Zvonaryova   F  23.0   172.0
# 270987  135508              Vera Igorevna Zvonaryova   F  23.0   172.0
# 270988  135508              Vera Igorevna Zvonaryova   F  27.0   172.0
# 271020  135526                          Dniel Zwickl   M  27.0   178.0
#
#         Weight      Team  NOC        Games  Year  Season     City  \
# ...

# %%
olympics[(olympics['Sport'].isin(sports)) & (olympics['City'] == 'Sydney')]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 184         82                Enrique Abaroa Martnez   M  26.0   183.0
# 498        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 499        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 1457       812                     David Dixie Adams   M  30.0   188.0
# 2022      1116      Eldijana Dana Aganovi (-Bentsen)   F  28.0   173.0
# ...        ...                                   ...  ..   ...     ...
# 269911  135043                         Nenad Zimonji   M  24.0   190.0
# 270775  135417                 Fabiola Zuluaga Amado   F  21.0   171.0
# 270776  135417                 Fabiola Zuluaga Amado   F  21.0   171.0
# 270979  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
# 270980  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
#
#         Weight                   Team  NOC        Games  Year  Season    City  \
# ...

# %% [markdown]
# filtros negativos

# %%
olympics[~(olympics['NOC'] == 'CHN')].head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
#Other possible option is
olympics[(olympics['NOC'] != 'CHN')].head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
#
#                                 Event Medal
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %% [markdown]
# Filtros con patrones

# %%
olympics_rou = olympics[olympics['NOC'] == 'ROU']
olympics_rou.head()
# Out:
#       ID            Name Sex   Age  Height  Weight     Team  NOC        Games  \
# 80    22   Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU  2016 Summer
# 876  506  Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU  1936 Summer
# 877  506  Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU  1936 Summer
# 878  506  Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU  1936 Summer
# 879  506  Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU  1936 Summer
#
#      Year  Season            City          Sport  \
# 80   2016  Summer  Rio de Janeiro  Weightlifting
# 876  1936  Summer          Berlin     Gymnastics
# 877  1936  Summer          Berlin     Gymnastics
# 878  1936  Summer          Berlin     Gymnastics
# 879  1936  Summer          Berlin     Gymnastics
#
#                                        Event Medal
# 80   Weightlifting Women's Super-Heavyweight   NaN
# 876   Gymnastics Men's Individual All-Around   NaN
# ...

# %%
olympics_rou[olympics_rou['Name'] == 'Nadia comanenci']
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
olympics_rou[olympics_rou['Name'].str.startswith('Nadia')]
# Out:
#           ID                           Name Sex   Age  Height  Weight  \
# 43773  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43774  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43775  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43776  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43777  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43778  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43779  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43780  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43781  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43782  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43783  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43784  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
#
# ...

# %% [markdown]
# Ejercicio Usain Bolt

# %%
olympics[olympics['Name'].str.startswith('Usain')]
# Out:
#           ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 24876  13029  Usain St. Leo Bolt   M  17.0   196.0    95.0  Jamaica  JAM
# 24877  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24878  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24879  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24880  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24881  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24882  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24883  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
# 24884  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
# 24885  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
#
#              Games  Year  Season            City      Sport  \
# 24876  2004 Summer  2004  Summer          Athina  Athletics
# ...

# %% [markdown]
# index, loc, iloc

# %%
olympics.head(10)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# ...

# %%
olympics.loc[0]
# Out:
# ID                                  1
# Name                        A Dijiang
# Sex                                 M
# Age                              24.0
# Height                          180.0
# Weight                           80.0
# Team                            China
# NOC                               CHN
# Games                     1992 Summer
# Year                             1992
# Season                         Summer
# City                        Barcelona
# Sport                      Basketball
# Event     Basketball Men's Basketball
# Medal                             NaN
# Name: 0, dtype: object

# %%
olympics.loc[5]
# Out:
# ID                                         5
# Name                Christine Jacoba Aaftink
# Sex                                        F
# Age                                     21.0
# Height                                 185.0
# Weight                                  82.0
# Team                             Netherlands
# NOC                                      NED
# Games                            1988 Winter
# Year                                    1988
# Season                                Winter
# City                                 Calgary
# Sport                          Speed Skating
# Event     Speed Skating Women's 1,000 metres
# Medal                                    NaN
# Name: 5, dtype: object

# %%
olympics.loc[20:25]
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 20   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 21   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 23   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 24   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 25   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 20  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 21  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 23  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 24  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 25  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
# ...

# %%
olympics.iloc[5]
# Out:
# ID                                         5
# Name                Christine Jacoba Aaftink
# Sex                                        F
# Age                                     21.0
# Height                                 185.0
# Weight                                  82.0
# Team                             Netherlands
# NOC                                      NED
# Games                            1988 Winter
# Year                                    1988
# Season                                Winter
# City                                 Calgary
# Sport                          Speed Skating
# Event     Speed Skating Women's 1,000 metres
# Medal                                    NaN
# Name: 5, dtype: object

# %% [markdown]
# seleccionar columnas

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics[['Name', 'Sport', 'Games']].head()
# Out:
#                        Name          Sport        Games
# 0                 A Dijiang     Basketball  1992 Summer
# 1                  A Lamusi           Judo  2012 Summer
# 2       Gunnar Nielsen Aaby       Football  1920 Summer
# 3      Edgar Lindenau Aabye     Tug-Of-War  1900 Summer
# 4  Christine Jacoba Aaftink  Speed Skating  1988 Winter

# %%
olympics.get(['Name', 'Sport', 'Games']).head()
# Out:
#                        Name          Sport        Games
# 0                 A Dijiang     Basketball  1992 Summer
# 1                  A Lamusi           Judo  2012 Summer
# 2       Gunnar Nielsen Aaby       Football  1920 Summer
# 3      Edgar Lindenau Aabye     Tug-Of-War  1900 Summer
# 4  Christine Jacoba Aaftink  Speed Skating  1988 Winter

# %%
olympics.loc[20:25, 'Name':'Team']
# Out:
#             Name Sex   Age  Height  Weight           Team
# 20  John Aalberg   M  31.0   183.0    72.0  United States
# 21  John Aalberg   M  31.0   183.0    72.0  United States
# 22  John Aalberg   M  33.0   183.0    72.0  United States
# 23  John Aalberg   M  33.0   183.0    72.0  United States
# 24  John Aalberg   M  33.0   183.0    72.0  United States
# 25  John Aalberg   M  33.0   183.0    72.0  United States

# %% [markdown]
# Cambiar nombre de columnas

# %%
olympics_2 = olympics.get(['Name', 'Sex', 'Age'])
olympics_2.head()
# Out:
#                        Name Sex   Age
# 0                 A Dijiang   M  24.0
# 1                  A Lamusi   M  23.0
# 2       Gunnar Nielsen Aaby   M  24.0
# 3      Edgar Lindenau Aabye   M  34.0
# 4  Christine Jacoba Aaftink   F  21.0

# %%
olympics_2.columns
# Out:
# Index(['Name', 'Sex', 'Age'], dtype='object')

# %%
olympics_2.columns = ['Nombe', 'Sexo', 'Edad']

# %%
olympics_2.head()
# Out:
#                       Nombe Sexo  Edad
# 0                 A Dijiang    M  24.0
# 1                  A Lamusi    M  23.0
# 2       Gunnar Nielsen Aaby    M  24.0
# 3      Edgar Lindenau Aabye    M  34.0
# 4  Christine Jacoba Aaftink    F  21.0

# %%
olympics_2 = olympics_2.rename(columns={"Nombe": "Nombre"})
olympics_2.head()
# Out:
#                      Nombre Sexo  Edad
# 0                 A Dijiang    M  24.0
# 1                  A Lamusi    M  23.0
# 2       Gunnar Nielsen Aaby    M  24.0
# 3      Edgar Lindenau Aabye    M  34.0
# 4  Christine Jacoba Aaftink    F  21.0

# %% [markdown]
# **Transformaciones entre columnas**

# %%
olympics_height = olympics['Height']/100

# %%
olympics['BMI'] = olympics['Height'] / (olympics['Height']/100) ** 2
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal        BMI
# 0       Basketball Men's Basketball   NaN  55.555556
# ...

# %%
olympics['BMI'].describe()
# Out:
# count    210945.000000
# mean         57.239791
# std           3.471422
# min          44.247788
# 25%          54.644809
# 50%          57.142857
# 75%          59.523810
# max          78.740157
# Name: BMI, dtype: float64

# %%
olympics[olympics['BMI']> 60]
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 32          13             Minna Maarit Aalto   F  30.0   159.0    55.5
# 33          13             Minna Maarit Aalto   F  34.0   159.0    55.5
# 79          21      Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 154         59         Ivan Nikolov Abadzhiev   M  24.0   164.0    71.0
# 155         59         Ivan Nikolov Abadzhiev   M  28.0   164.0    71.0
# ...        ...                            ...  ..   ...     ...     ...
# 271061  135549  Nataliya Vasilyevna Zyatikova   F  27.0   162.0    53.0
# 271062  135550      Vera Vasilyevna Zyatikova   F  27.0   161.0    53.0
# 271063  135550      Vera Vasilyevna Zyatikova   F  27.0   161.0    53.0
# 271064  135550      Vera Vasilyevna Zyatikova   F  27.0   161.0    53.0
# 271065  135550      Vera Vasilyevna Zyatikova   F  27.0   161.0    53.0
#
#             Team  NOC        Games  Year  Season            City  \
# ...

# %%
sns.histplot(olympics['BMI'], bins= 20)
# Out:
# <AxesSubplot: xlabel='BMI', ylabel='Count'>

# %%
olympics['Olympic'] = olympics['Year'].astype('str')
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal        BMI Olympic
# 0       Basketball Men's Basketball   NaN  55.555556    1992
# ...

# %%
olympics['Sex_Numeric'] = olympics['Sex'].map({'M': 1, 'F': 0})

# %%
olympics.loc[:10, ['Sex', 'Sex_Numeric']]
# Out:
#    Sex  Sex_Numeric
# 0    M            1
# 1    M            1
# 2    M            1
# 3    M            1
# 4    F            0
# 5    F            0
# 6    F            0
# 7    F            0
# 8    F            0
# 9    F            0
# 10   M            1

# %%
def es_adulto(edad):
    if edad > 17:
        return 1
    else:
        return 0

# %%
olympics['Adult'] = olympics['Age'].apply(es_adulto)
